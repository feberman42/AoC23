# %%
strings = open('input').read().strip('\n').split(',')
strings
# Out:
# ['csp-',
#  'tbbz-',
#  'kzdgsd-',
#  'rp-',
#  'smp=6',
#  'vxj-',
#  'mx=2',
#  'bxkbhs-',
#  'ct-',
#  'dtt=4',
#  'kxg=4',
#  'sx-',
#  'khdz=4',
#  'mdcjbh-',
#  'cb=7',
#  'gjgvs-',
#  'gq-',
#  'cmtf=5',
#  'mx-',
#  'jq-',
#  'zqlsk=8',
#  'bq-',
#  'qd-',
#  'cfl-',
#  'hpb=3',
#  'gv-',
#  'zx-',
#  'qlg=2',
#  'bnv=1',
#  'qlpx-',
#  'ztlr=8',
#  'bq=9',
#  'sbtm-',
#  'gsh-',
#  'qp-',
#  'brf-',
#  'rddbnz-',
#  'bb=2',
#  'nscj-',
#  'kgb-',
#  'rpz=7',
#  'xqfxjq=9',
#  'gmf=8',
#  'qvj=7',
#  'fhxb=9',
#  'hfdpr=4',
#  'zqlsk-',
#  'cskx-',
#  'ct=7',
#  'hmfm=1',
#  'cpq=1',
#  'zl-',
#  'vxj=1',
#  'hf-',
#  'nscj=8',
#  'zqlsk=8',
#  'pb=1',
#  'mxpc-',
#  'vbmcz-',
#  'rp=7',
#  'lnp=7',
#  'mj-',
#  'gkxd=7',
#  'cpdx-',
#  'cx=5',
#  'dgc=1',
#  'qpvl-',
#  'mv-',
#  'xlr=5',
#  'ppdf-',
#  'qhv-',
#  'drnm=9',
#  'mx-',
#  'vmj-',
#  'bvt=4',
#  'gbv=3',
#  'bnv=2',
#  'bblh-',
#  'kst-',
#  'lvb-',
#  'qr=7',
#  'bz=1',
#  'nrsbg-',
#  'klp-',
#  'gd=8',
# ...

# %%
def	hash(s: str) -> int:
	value = 0
	for c in s:
		value += ord(c)
		value *= 17
		value = value % 256
	return value

# %%
sum = 0
for s in strings:
	sum += hash(s)
sum
# Out:
# 514025

# %%
hash('qp')
# Out:
# 1
